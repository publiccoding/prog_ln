# %%
import pandas as pd

# # A one-dimensional labeled array a capable of holding any data type
# s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])
# print(s)

# %%
# data = {'Country': ['Belgium', 'India', 'Brazil'],
# 'Capital': ['Brussels', 'New Delhi', 'Brasília'],
# 'Population': [11190846, 1303171035, 207847528]}

# df = pd.DataFrame(data, index=['value1','value2','value3'],columns=['Country','Capital','Population'])
# print(df.head().T) # Transpose 
# print(df.head())

# %%
# df=pd.read_csv('Code.csv',nrows=5)
# df.to_csv('DataFrames.csv')
# df=pd.read_csv('DataFrames.csv')
# print(df)
# write DataFrame into xlsx file format install xlsxwriter then mention the same in here 
# df.to_excel('mydata.xlsx', sheet_name='sheet1')
# data = pd.read_excel('mydata.xlsx')
# print(data)

# %%
# read csv file and write into xls file format
from collections import OrderedDict, Counter
from pandas.io.excel import ExcelWriter
import matplotlib.pyplot as plt 
# xlsx = pd.ExcelFile('mydata.xlsx', header=False)
# print(xlsx.sheet_names) # read the no of sheet from xls file 
# sheet_name= xlsx.sheet_names
# orderdict =xlsx.parse(sheet_name)
# col = Counter()
# for k in orderdict:
#     col.update(k)
# print(orderdict.values())
# print(orderdict.keys())
# df = pd.DataFrame(orderdict.values())
# print(df)
# df = pd.read_excel(xlsx, ['sheet1'])
# print(list(df))


# csv_list = ['Code.csv','code2.csv','DataFrames.csv']

# with ExcelWriter('Tested.xlsx') as ew :
#     for cs in csv_list:
#          pd.read_csv(cs).to_excel(ew, sheet_name=cs[:-4])
            
# df = pd.read_excel('Tested.xlsx', sheet_name='Code')
# df['JURISDICTION NAME'].plot()
# plt.show()
#df.to_csv('CodeTested.csv')


# # writing multiple data frame to multiple excel file 
# for i in xrange(n):
#     filename = 'output_P%s.xlsx' % (1+i)
#     dfLP[i].to_excel(filename, sheet_name='Sheet1')

# # writing multiple data frame to single excel file with multiple sheets
# for i in xrange(n):
#     sheet = 'sheet%s' % (1+i)
#     dfLP[i].to_excel('filename.xlsx', sheet_name=sheet)

# %%
import pandas as pd
data = {
'Country': ['Belgium', 'India', 'Brazil'],
'Capital': ['Brussels', 'New Delhi', 'Brasília'],
'Population': [11190846, 1303171035, 207847528]
}

df = pd.DataFrame(data, index=['value1','value2','value3'],columns=['Country','Capital','Population'])
# print(df['Country'])
# print(df.iloc[[0],[0]]) # By position
# print(df.loc[['value1'],['Country']]) # By label 
# print(df.ix[1,'Capital'])
#print(df[df['Population'] > 1200000000])
#df['Country']['value1'] = 'Balgiumam'
# print(df.head())
# df.drop('Country', axis=1)  # 
# print(df.head())
# df.sort_index;print(df.head())
# print(df.sort_values(by='Country'))
# sorted_df=unsorted_df.sort_index(axis=1)
# sorted_df = unsorted_df.sort_values(by='col1')
# sorted_df = unsorted_df.sort_values(by='col1' ,kind='mergesort')
# print(df.rank())
# print(df.shape)
#print(df.index)
#print(df.columns)
#print(df.info())
#print(df.count())
#print(df.sum())
# print(df.cumsum())
# print(df.min());print(df.max())
#print(df.idxmin());print(df.idxmax())

# %%
import pandas as pd
data = {
'Country': ['Belgium', 'India', 'Brazil','America'],
'Capital': ['Brussels', 'New Delhi', 'Brasília', 'New York'],
'Population': [11190846, 1303171035, 207847528,0]
}

df = pd.DataFrame(data)
#print(df.head())
#print(df[df.Population != 0]) ; print(df.query('Population !=0'))  # both give the same functionality 
# print(df.drop([0])); # drop by index but original value will not changed 
# print(df.drop('Capital', axis=1)) # drop by column value axis should be present =1 
#print(df.index[3])
#print(df.mean())
#print(df.describe())
#print(df.median())
# print (df.describe(include='all')) # object − Summarizes String columns, number − Summarizes Numeric columns,all − Summarizes all columns together (Should not pass it as a list value)
# print(df.describe(include='object'))
# print(df.describe(include='number'))

# %%
import pandas as pd
import numpy as np

N=20

df = pd.DataFrame({
   'A': pd.date_range(start='2016-01-01',periods=N,freq='D'),
   'x': np.linspace(0,stop=N-1,num=N),
   'y': np.random.rand(N),
   'C': np.random.choice(['Low','Medium','High'],N).tolist(),
   'D': np.random.normal(100, 10, size=(N)).tolist()
})
# print(df.head())

#reindex the DataFrame
df_reindexed = df.reindex(index=[0,2,5], columns=['A', 'C', 'B'])  # missing value will be allocated as NaN 
# print(df_reindexed.head())
# df1 = df1.reindex_like(df2) # based on the other dataframe. 

# df1 = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
# df2 = pd.DataFrame(np.random.randn(2,3),columns=['col1','col2','col3'])
# print(df1); print(df2)
# print(df2.reindex_like(df1, method='nearest'))

# df1 = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
# print (df1)
# print ("After renaming the rows and columns:")
# print(df1.rename(columns={'col1' : 'c1', 'col2' : 'c2'},
# index = {0 : 'apple', 1 : 'banana', 2 : 'durian'}))

# %%
# Pandas function pipe and apply 

import pandas as pd
import numpy as np

N=20

df = pd.DataFrame({
   'A': pd.date_range(start='2016-01-01',periods=N,freq='D'),
   'x': np.linspace(0,stop=N-1,num=N),
   'y': np.random.rand(N),
   'C': np.random.choice(['Low','Medium','High'],N).tolist(),
   'D': np.random.normal(100, 10, size=(N)).tolist()
})
# print(df.head())


# data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
#         'year': [2012, 2012, 2013, 2014, 2014], 
#         'reports': [4, 24, 31, 2, 3],
#         'coverage': [25, 94, 57, 62, 70]}
# df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])
# print(df.head())

f = lambda x:x*x

def times100(x):
    if type(x) is str:
        return x.upper()
    elif x:
        return 100 * x
    else:
        return x


# print(df['year'].apply(f))
# print(df['reports'].map(f))
# print(df.applymap(times100))

#print(df.head())

# for col in df:
#     print(col)
# for col , val in df.head().iteritems():
#     print(col,val)
# for row_ind, row in df.head().iterrows():
#     print(row_ind,row)
for row in df.head().itertuples():
    print(row)
# Out:
# Pandas(Index=0, A=Timestamp('2016-01-01 00:00:00'), C='High', D=107.46424892637614, x=0.0, y=0.9635800211314509)
# Pandas(Index=1, A=Timestamp('2016-01-02 00:00:00'), C='High', D=105.33721592685757, x=1.0, y=0.5285427270107793)
# Pandas(Index=2, A=Timestamp('2016-01-03 00:00:00'), C='High', D=91.81394023413597, x=2.0, y=0.63536952850202)
# Pandas(Index=3, A=Timestamp('2016-01-04 00:00:00'), C='Medium', D=101.86809004471371, x=3.0, y=0.02762517333667769)
# Pandas(Index=4, A=Timestamp('2016-01-05 00:00:00'), C='Medium', D=108.42162938549991, x=4.0, y=0.09996755688512038)
