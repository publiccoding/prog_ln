# %%
import matplotlib.pyplot as plt 
import numpy as np 

#plt.plot([1,2,4],[6,3,1])
#plt.show()

# x= [i for i in np.arange(1,8)]
# y= [i for i in np.arange(0,7)]
# x2 = [1,3,4]
# y2 = [10,14,12]

# plt.plot(x,y, label='this is x and y value')
# plt.plot(x2,y2, label='This is x2, y2 value')
# plt.xlabel('Plot Number')
# plt.ylabel('Important var')
# plt.title('It is interesting grap \ncheck it out')
# plt.legend()
# plt.show()

# x = [2,4,6,8,10]
# y = [6,7,8,2,4]

# x1 = [1,3,5,7,9,11]
# y1 = [7,8,9,2,3,2]


# plt.bar(x,y, label='Bars1', color='r')
# plt.bar(x1,y1, label='Bars2')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend()
# plt.show()


# ages=[11,33,22,53,32,3,89,57,49]
# ids = [x-1 for x in range(len(ages))]
# plt.hist(ages,ids,histtype='bar',rwidth=0.5,label='population ids ')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend()
# plt.show()

# ages=[11,33,22,53,32,3,89,57,49]
# ids = [x-1 for x in range(len(ages))]
# plt.scatter(ages,ids,label='population ids ', color='r', marker='*', s=100)
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend()
# plt.show()


ages=[11,33,22,53,32]

slep=[7,3,6,11,8]
eat=[3,4,9,0,2]
work=[8,5,7,2,0]
play=[9,0,4,5,2]
plt.plot([],[],color='r', label='ages',linewidth=5)
plt.plot([],[],color='c', label='Sleeping',linewidth=5)
plt.plot([],[],color='k', label='eating',linewidth=5)
plt.plot([],[],color='b', label='working',linewidth=5)
plt.plot([],[],color='m', label='playing',linewidth=5)

plt.stackplot(ages,slep,eat,work,play,colors=['r','c','k','b','m'])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()


slices=[7,2,2,13]
activities = ['sleeping','eating','working','playing']
cols=['c','m','r','b']
plt.pie(slices, labels=activities, colors=cols, startangle=90,shadow=True, explode=(0,0.1,0.3,0), autopct='%1.1f%%')
plt.title('interesting this is \nsuper pie chart')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import csv

# x=[]
# y=[]
# with open('data.csv', 'r') as csvfile:
#     plots=csv.reader(csvfile,delimiter=',')
#     for row in plots:
#         x.append(int(row[0]))
#         y.append(int(row[1]))
        
# plt.plot(x,y,label="loaded from csv file ")
# plt.xlabel('x')
# plt.ylabel('y')

# plt.legend()
# plt.show()


# x, y ,z = np.loadtxt('data.csv', delimiter=',',unpack=True)

# plt.plot(x,y,z,label="loaded from csv file ")
# plt.xlabel('x')
# plt.ylabel('y')
# plt.grid(True)

# plt.legend()
# plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import csv
import urllib
import matplotlib.dates as mdates



def graph_data(stock):
    stock_price='http://chartapi.finance.yahoo.com/instrument/1.0/'+stock+'/chartdata;type=quote;range=10y/csv'
    source_code = urllib.request.urlopen(stock_price).read().decode()
    print(source_code)

# %%
# import random 
# import matplotlib.pyplot as plt 

# fig = plt.figure()

# def create_plots():
#     xs = []
#     ys = []
    
#     for i in range(10):
#         x=i
#         y=random.randrange(10)
        
#         xs.append(x)
#         ys.append(y)
        
#     return xs, ys

# ax1 = fig.add_subplot(221)
# ax2 = fig.add_subplot(222)
# ax3 = fig.add_subplot(212)

# x,y = create_plots()
# ax1.plot(x,y)

# x,y = create_plots()
# ax2.plot(x,y)

# x,y = create_plots()
# ax3.plot(x,y)

# plt.show()

# %%
import random 
import matplotlib.pyplot as plt 

fig = plt.figure()

def create_plots():
    xs = []
    ys = []
    
    for i in range(10):
        x=i
        y=random.randrange(10)
        
        xs.append(x)
        ys.append(y)
        
    return xs, ys

ax1 = plt.subplot2grid((6,2),(0,0),rowspan=1, colspan=1)
ax = plt.subplot2grid((6,2),(0,1),rowspan=1, colspan=1)
ax2 = plt.subplot2grid((6,1),(1,0),rowspan=4, colspan=1)
ax3 = plt.subplot2grid((6,1),(5,0),rowspan=1, colspan=1)

x,y = create_plots()
ax1.plot(x,y)

x,y = create_plots()
ax2.plot(x,y)

x,y = create_plots()
ax3.plot(x,y)

plt.show()
